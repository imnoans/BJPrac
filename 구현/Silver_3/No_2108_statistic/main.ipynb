# %% [markdown]
# # 문제
#
# ---
#
# 수를 처리하는 것은 통계학에서 상당히 중요한 일이다. 통계학에서 N개의 수를 대표하는 기본 통계값에는 다음과 같은 것들이 있다. 단, N은 홀수라고 가정하자.
#
# 산술평균 : N개의 수들의 합을 N으로 나눈 값
# 중앙값 : N개의 수들을 증가하는 순서로 나열했을 경우 그 중앙에 위치하는 값
# 최빈값 : N개의 수들 중 가장 많이 나타나는 값
# 범위 : N개의 수들 중 최댓값과 최솟값의 차이
# N개의 수가 주어졌을 때, 네 가지 기본 통계값을 구하는 프로그램을 작성하시오.
#
# # 입력
#
# ---
#
# 첫째 줄에 수의 개수 N(1 ≤ N ≤ 500,000)이 주어진다. 단, N은 홀수이다. 그 다음 N개의 줄에는 정수들이 주어진다. 입력되는 정수의 절댓값은 4,000을 넘지 않는다.
#
# # 출력
#
# ---
#
# 첫째 줄에는 산술평균을 출력한다. 소수점 이하 첫째 자리에서 반올림한 값을 출력한다.
#
# 둘째 줄에는 중앙값을 출력한다.
#
# 셋째 줄에는 최빈값을 출력한다. 여러 개 있을 때에는 최빈값 중 두 번째로 작은 값을 출력한다.
#
# 넷째 줄에는 범위를 출력한다.

# %%
n = int(input())

avg, mid, mode, ran = 0, 0, 0, 0
myMax = 0
nums = []
counts = []
total = 0

for i in range(n) :
    a = int(input())
    nums.append(a)
    total += a

nums.sort()
print(nums)
pre = 0

if n == 1 :
    avg = nums[0]
    mid = nums[0]
    mode = nums[0]
    ran = 0
else :
    for i in range(1, n, 1) :
        if nums[i] == nums[i - 1] :
            counts.append(0)
            counts[pre] += 1
            myMax = max(myMax, counts[pre])
        else :
            counts.append(0)
            pre = i
    counts.append(0)

    modes = []
    for i in range(len(counts)):
        if myMax == counts[i]:
            modes.append(nums[i])
    
    print(counts)
    print(modes)
    if len(modes) > 1 :
        modes.sort()
        mode = modes[1]
    else :
        mode = modes[0]


avg = round(total / n)
mid = nums[n // 2]
ran = nums[n - 1] - nums[0]

print(avg)
print(mid)
print(mode)
print(ran)
# Out:
# [-2, 1, 2, 3, 8]
# [0, 0, 0, 0, 0]
# [-2, 1, 2, 3, 8]
# 2
# 2
# 1
# 10

# %%
n = int(input())
arr = []

sum = 0

for _ in range(n):
  k = int(input())
  arr.append(k)
  sum += k

if n == 1 :
  print(arr[0])
  print(arr[0])
  print(arr[0])
  print(0)
else :
  arr.sort()

  myMax = arr[n - 1]
  myMin = arr[0]

  

  if myMin >= 0:
    frequence = [0] * (myMax+1)
    field = myMax+1
  else:
    frequence = [0] * (myMax+(abs(myMin)+1))
    field = myMax+(abs(myMin)+1)

  print(arr)

  freqMax = 0
  for i in arr:
    if i < 0 :
      frequence[myMax - i] += 1
      freqMax = max(freqMax, frequence[myMax - i])
    else :
      frequence[i] += 1
      freqMax = max(freqMax, frequence[i])

  print(frequence)
  arr2 = []

  for i in range(field):
    if freqMax == frequence[i]:
      if myMax >= i :
        arr2.append(i)
      else:
        arr2.append(-(i - myMax))

  arr2.sort()

  print(arr2)

  print(round(sum / n))
  print(arr[n//2])
  if len(arr2) == 1:
    print(arr2[0])
  else:
    print(arr2[1])
  print(myMax-myMin)
# Out:
# [-2, 1, 2, 3, 8]
# [0, 1, 1, 1, 0, 0, 0, 0, 1, 0, 1]
# [-2, 1, 2, 3, 8]
# 2
# 2
# 1
# 10

# %% [markdown]
# # 풀이
#
# ---
#
#     n = int(input())
#
# 우선 수의 개수 n을 입력받는다
#
#     arr = []
#
#     sum = 0
#
# 입력받을 수를 저장할 리스트 arr과 총합을 저장하기 위한 sum을 정의한다
#
#     for _ in range(n):
#     k = int(input())
#     arr.append(k)
#     sum += k
#
# n개의 수를 입력받아 arr에 저장하고 sum에 더한다
#
#     if n == 1 :
#     print(arr[0])
#     print(arr[0])
#     print(arr[0])
#     print(0)
#
# 만약 n이 1이라면 평균값, 중앙값, 최빈값 모두 arr[0]이고 범위는 0이므로 출력하고 종료한다
#
#     else :
#     arr.sort()
#
# n이 1이 아닐 경우 우선 arr을 정렬한다
#
#     myMax = arr[n - 1]
#     myMin = arr[0]
#
# 최대값과 최솟값을 저장한다
#
#     if myMin >= 0:
#         frequence = [0] * (myMax+1)
#         field = myMax+1
#
# 만약 최솟값이 양수라면 최대값+1 개 만큼의 index를 가지는 리스트 frequence를 생성한 후 field(배열의 크기)에 myMax+1을 대입한다
#
#     else:
#         frequence = [0] * (myMax+(abs(myMin)+1))
#         field = myMax+(abs(myMin)+1)
#
# 최솟값이 음수라면 최대값 이후에 음수의 개수를 저장하기 위해 myMax - myMin + 1개 만큼의 index를 가지는 리스트 frequence를 생성한 후 field(배열의 크기)에 대입한다
#
#     freqMax = 0
#     for i in arr:
#         if i < 0 :
#         frequence[myMax - i] += 1
#         freqMax = max(freqMax, frequence[myMax - i])
#         else :
#         frequence[i] += 1
#         freqMax = max(freqMax, frequence[i])
#
# 최빈값을 찾기 위하여 나온 개수의 최댓값을 저장하는 freqMax를 정의한다
# arr의 요소 중 음수가 있다면 myMax에 뒤에 있는 음수의 개수를 증가시키고 freqMax를 계산한다
# 양수라면 해당 값을 인덱스로 사용하여 증가시킨다
#
#     print(frequence)
#     arr2 = []
#
#     for i in range(field):
#         if freqMax == frequence[i]:
#         if myMax >= i :
#             arr2.append(i)
#         else:
#             arr2.append(-(i - myMax))
#
#     arr2.sort()
#
#     print(arr2)
#
#     print(round(sum / n))
#     print(arr[n//2])
#     if len(arr2) == 1:
#         print(arr2[0])
#     else:
#         print(arr2[1])
#     print(myMax-myMin)

# %%
from collections import Counter
N= int(input())
arr = []
#값 입력
total = 0
for i in range(N):
    a = int(input())
    total += a
    arr.append(a)
#산술평균
avg = total/N
avg = round(avg)
print(avg)
#중앙값
arr.sort()
print(arr[N // 2])
#최빈값
cnt = Counter(arr).most_common()
if cnt[0][1]== cnt[1][1]:
    print(cnt[1][0])
else:
    print(cnt[0][0])


#범위
print(arr[len(arr)-1]-arr[0])
